# %%
import numpy as np
import pandas
from keras.layers import *
from keras.models import Sequential, Model
import keras
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def zeroMean(dataMat):        
    meanVal=np.mean(dataMat,axis=0)     #get mean by columns
    newData=dataMat-meanVal  
    return newData,meanVal


def percentage2n(eigVals,percentage):  
    sortArray=np.sort(eigVals)          #ascend order 
    sortArray=sortArray[-1::-1]           
    arraySum=sum(sortArray)  
    tmpSum=0  
    num=0  
    for i in sortArray:  
        tmpSum+=i  
        num+=1  
        if tmpSum>=arraySum*percentage:  
            return num  


def pca(dataMat,percentage=0.99):  
    newData,meanVal=zeroMean(dataMat)  
    covMat=np.cov(newData,rowvar=0)      #covariance  
    eigVals,eigVects=np.linalg.eig(np.mat(covMat))      
    n=percentage2n(eigVals,percentage)                 #need n dimensionol data to get the convariance percentage
    n = 6   # pca of 2017 rookies data is 6 dimentional 
    eigValIndice=np.argsort(eigVals)            #ascend order 
    n_eigValIndice=eigValIndice[-1:-(n+1):-1]   
    n_eigVect=eigVects[:,n_eigValIndice]        
    lowDDataMat=newData*n_eigVect               #lower dimensional data  
    reconMat=(lowDDataMat*n_eigVect.T)+meanVal  #reconstruct data  
    return lowDDataMat,reconMat

# %%
df = pandas.read_csv("04-16_NBA_rookies_data.csv", header=None)
df1 = pandas.read_csv("04-16_NBA_rookies_label.csv",header=None)
df_test = pandas.read_csv("2017rookies_data.csv",header=None)
df1_test = pandas.read_csv("2017rookies_name.csv",header=None)
ds = df.values
ds1 = df1.values
lowDDataMat,reconMat=pca(ds)  #pca
ds_test = df_test.values
lowDDataMat1,reconMat1=pca(ds_test)  #pca
ds1_test = df1_test.values

# %%
x_train = lowDDataMat[:,0:6]
y_train = ds1[:,1]
x_test = lowDDataMat1[:,0:6]
y_test = ds1_test[:,0]

dim = x_train.shape[1]
model = Sequential()
model.add(Dense(100, input_dim=dim, activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop',metrics=["accuracy"])

# %%
# Change log_dir for differnt activation function, change the number for every run.
tbCallBack = keras.callbacks.TensorBoard(log_dir='tensorboard/tanh/5', histogram_freq=0, write_graph=True, write_images=True)

# %%
idx = list(range(x_train.shape[0]))
np.random.shuffle(idx)
hist = model.fit(x_train[idx],y_train[idx],validation_split=0.2,epochs=85,shuffle=True, callbacks = [tbCallBack])
dnn_predict = model.predict_classes(x_test)
print(sum(dnn_predict))
print(y_test[dnn_predict == 1])
# Out:
# Train on 359 samples, validate on 90 samples
# Epoch 1/85
# 359/359 [==============================] - 0s 42us/step - loss: 0.1218 - acc: 0.9526 - val_loss: 0.0746 - val_acc: 0.9556
# Epoch 2/85
# 359/359 [==============================] - 0s 46us/step - loss: 0.1074 - acc: 0.9526 - val_loss: 0.0712 - val_acc: 0.9667
# Epoch 3/85
# 359/359 [==============================] - 0s 52us/step - loss: 0.1105 - acc: 0.9554 - val_loss: 0.0763 - val_acc: 0.9556
# Epoch 4/85
# 359/359 [==============================] - 0s 53us/step - loss: 0.1091 - acc: 0.9526 - val_loss: 0.0780 - val_acc: 0.9556
# Epoch 5/85
# 359/359 [==============================] - 0s 45us/step - loss: 0.1000 - acc: 0.9499 - val_loss: 0.0986 - val_acc: 0.9556
# Epoch 6/85
# 359/359 [==============================] - 0s 42us/step - loss: 0.0975 - acc: 0.9610 - val_loss: 0.0916 - val_acc: 0.9556
# Epoch 7/85
# 359/359 [==============================] - 0s 47us/step - loss: 0.0966 - acc: 0.9666 - val_loss: 0.0959 - val_acc: 0.9556
# Epoch 8/85
# 359/359 [==============================] - 0s 46us/step - loss: 0.1070 - acc: 0.9554 - val_loss: 0.0900 - val_acc: 0.9556
# Epoch 9/85
# 359/359 [==============================] - 0s 53us/step - loss: 0.0740 - acc: 0.9721 - val_loss: 0.0830 - val_acc: 0.9556
# Epoch 10/85
# 359/359 [==============================] - 0s 49us/step - loss: 0.1334 - acc: 0.9499 - val_loss: 0.0987 - val_acc: 0.9444
# Epoch 11/85
# 359/359 [==============================] - 0s 64us/step - loss: 0.0808 - acc: 0.9666 - val_loss: 0.1013 - val_acc: 0.9444
# Epoch 12/85
# 359/359 [==============================] - 0s 47us/step - loss: 0.0973 - acc: 0.9554 - val_loss: 0.0898 - val_acc: 0.9556
# Epoch 13/85
# 359/359 [==============================] - 0s 48us/step - loss: 0.1286 - acc: 0.9499 - val_loss: 0.1109 - val_acc: 0.9333
# Epoch 14/85
# 359/359 [==============================] - 0s 48us/step - loss: 0.1173 - acc: 0.9443 - val_loss: 0.1091 - val_acc: 0.9444
# Epoch 15/85
# 359/359 [==============================] - 0s 52us/step - loss: 0.0869 - acc: 0.9749 - val_loss: 0.1113 - val_acc: 0.9333
# Epoch 16/85
# 359/359 [==============================] - 0s 50us/step - loss: 0.0944 - acc: 0.9582 - val_loss: 0.1076 - val_acc: 0.9444
# Epoch 17/85
# 359/359 [==============================] - 0s 406us/step - loss: 0.0891 - acc: 0.9554 - val_loss: 0.1044 - val_acc: 0.9444
# Epoch 18/85
# 359/359 [==============================] - 0s 48us/step - loss: 0.0794 - acc: 0.9749 - val_loss: 0.1197 - val_acc: 0.9333
# Epoch 19/85
# 359/359 [==============================] - 0s 50us/step - loss: 0.0863 - acc: 0.9638 - val_loss: 0.1004 - val_acc: 0.9444
# Epoch 20/85
# 359/359 [==============================] - 0s 43us/step - loss: 0.1000 - acc: 0.9638 - val_loss: 0.1173 - val_acc: 0.9333
# Epoch 21/85
# 359/359 [==============================] - 0s 41us/step - loss: 0.0956 - acc: 0.9526 - val_loss: 0.1133 - val_acc: 0.9333
# Epoch 22/85
# 359/359 [==============================] - 0s 43us/step - loss: 0.0890 - acc: 0.9638 - val_loss: 0.0884 - val_acc: 0.9556
# Epoch 23/85
# 359/359 [==============================] - 0s 46us/step - loss: 0.1059 - acc: 0.9526 - val_loss: 0.1080 - val_acc: 0.9333
# Epoch 24/85
# 359/359 [==============================] - 0s 47us/step - loss: 0.0982 - acc: 0.9582 - val_loss: 0.1110 - val_acc: 0.9333
# Epoch 25/85
# 359/359 [==============================] - 0s 63us/step - loss: 0.0864 - acc: 0.9805 - val_loss: 0.1095 - val_acc: 0.9444
# Epoch 26/85
# 359/359 [==============================] - 0s 553us/step - loss: 0.1129 - acc: 0.9526 - val_loss: 0.1127 - val_acc: 0.9333
# Epoch 27/85
# 359/359 [==============================] - 0s 47us/step - loss: 0.0928 - acc: 0.9499 - val_loss: 0.1149 - val_acc: 0.9333
# Epoch 28/85
# 359/359 [==============================] - 0s 43us/step - loss: 0.1017 - acc: 0.9554 - val_loss: 0.1118 - val_acc: 0.9444
# Epoch 29/85
# 359/359 [==============================] - 0s 55us/step - loss: 0.0864 - acc: 0.9694 - val_loss: 0.1186 - val_acc: 0.9444
# Epoch 30/85
# 359/359 [==============================] - 0s 50us/step - loss: 0.0857 - acc: 0.9666 - val_loss: 0.1061 - val_acc: 0.9444
# Epoch 31/85
# 359/359 [==============================] - 0s 58us/step - loss: 0.0891 - acc: 0.9499 - val_loss: 0.1100 - val_acc: 0.9444
# Epoch 32/85
# 359/359 [==============================] - 0s 51us/step - loss: 0.0932 - acc: 0.9666 - val_loss: 0.1175 - val_acc: 0.9333
# Epoch 33/85
# 359/359 [==============================] - 0s 59us/step - loss: 0.0905 - acc: 0.9666 - val_loss: 0.1112 - val_acc: 0.9222
# Epoch 34/85
# 359/359 [==============================] - 0s 61us/step - loss: 0.0894 - acc: 0.9610 - val_loss: 0.1090 - val_acc: 0.9444
# Epoch 35/85
# 359/359 [==============================] - 0s 60us/step - loss: 0.1136 - acc: 0.9526 - val_loss: 0.1020 - val_acc: 0.9444
# Epoch 36/85
# 359/359 [==============================] - 0s 566us/step - loss: 0.0906 - acc: 0.9638 - val_loss: 0.1010 - val_acc: 0.9444
# Epoch 37/85
# 359/359 [==============================] - 0s 41us/step - loss: 0.1119 - acc: 0.9526 - val_loss: 0.1076 - val_acc: 0.9333
# Epoch 38/85
# 359/359 [==============================] - 0s 41us/step - loss: 0.0910 - acc: 0.9666 - val_loss: 0.1237 - val_acc: 0.9333
# Epoch 39/85
# 359/359 [==============================] - 0s 44us/step - loss: 0.0787 - acc: 0.9666 - val_loss: 0.1234 - val_acc: 0.9111
# Epoch 40/85
# 359/359 [==============================] - 0s 46us/step - loss: 0.0937 - acc: 0.9554 - val_loss: 0.1184 - val_acc: 0.9222
# Epoch 41/85
# 359/359 [==============================] - 0s 41us/step - loss: 0.0929 - acc: 0.9610 - val_loss: 0.1278 - val_acc: 0.9333
# Epoch 42/85
# 359/359 [==============================] - 0s 42us/step - loss: 0.0743 - acc: 0.9805 - val_loss: 0.1256 - val_acc: 0.9222
# Epoch 43/85
# 359/359 [==============================] - 0s 46us/step - loss: 0.0820 - acc: 0.9694 - val_loss: 0.1292 - val_acc: 0.9111
# Epoch 44/85
# 359/359 [==============================] - 0s 44us/step - loss: 0.0670 - acc: 0.9721 - val_loss: 0.1151 - val_acc: 0.9444
# Epoch 45/85
# 359/359 [==============================] - 0s 44us/step - loss: 0.1036 - acc: 0.9554 - val_loss: 0.1262 - val_acc: 0.9111
# Epoch 46/85
# 359/359 [==============================] - 0s 47us/step - loss: 0.0717 - acc: 0.9721 - val_loss: 0.1083 - val_acc: 0.9444
# Epoch 47/85
# 359/359 [==============================] - 0s 42us/step - loss: 0.0807 - acc: 0.9638 - val_loss: 0.1164 - val_acc: 0.9444
# Epoch 48/85
#  32/359 [=>............................] - ETA: 0s - loss: 0.0271 - acc: 1.0000
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.183780). Check your callbacks.
#   % delta_t_median)
# 359/359 [==============================] - 0s 574us/step - loss: 0.0630 - acc: 0.9777 - val_loss: 0.1303 - val_acc: 0.9222
# Epoch 49/85
# 359/359 [==============================] - 0s 42us/step - loss: 0.0878 - acc: 0.9610 - val_loss: 0.1134 - val_acc: 0.9444
# Epoch 50/85
# 359/359 [==============================] - 0s 43us/step - loss: 0.0800 - acc: 0.9582 - val_loss: 0.1103 - val_acc: 0.9444
# Epoch 51/85
# 359/359 [==============================] - 0s 40us/step - loss: 0.0955 - acc: 0.9582 - val_loss: 0.1145 - val_acc: 0.9444
# Epoch 52/85
# 359/359 [==============================] - 0s 47us/step - loss: 0.0704 - acc: 0.9777 - val_loss: 0.1155 - val_acc: 0.9444
# Epoch 53/85
# 359/359 [==============================] - 0s 48us/step - loss: 0.0856 - acc: 0.9610 - val_loss: 0.1340 - val_acc: 0.9111
# Epoch 54/85
# 359/359 [==============================] - 0s 52us/step - loss: 0.0870 - acc: 0.9666 - val_loss: 0.1625 - val_acc: 0.9000
# Epoch 55/85
# 359/359 [==============================] - 0s 43us/step - loss: 0.1162 - acc: 0.9526 - val_loss: 0.1227 - val_acc: 0.9333
# Epoch 56/85
# 359/359 [==============================] - 0s 43us/step - loss: 0.0813 - acc: 0.9638 - val_loss: 0.1302 - val_acc: 0.9222
# Epoch 57/85
# 359/359 [==============================] - 0s 41us/step - loss: 0.0810 - acc: 0.9694 - val_loss: 0.1346 - val_acc: 0.9111
# Epoch 58/85
# 359/359 [==============================] - 0s 41us/step - loss: 0.0799 - acc: 0.9638 - val_loss: 0.1372 - val_acc: 0.9111
# Epoch 59/85
# 359/359 [==============================] - 0s 41us/step - loss: 0.1039 - acc: 0.9554 - val_loss: 0.1205 - val_acc: 0.9444
# Epoch 60/85
# 359/359 [==============================] - 0s 65us/step - loss: 0.0934 - acc: 0.9526 - val_loss: 0.1264 - val_acc: 0.9222
# Epoch 61/85
# 359/359 [==============================] - 0s 60us/step - loss: 0.0771 - acc: 0.9833 - val_loss: 0.1201 - val_acc: 0.9222
# Epoch 62/85
# 359/359 [==============================] - 0s 55us/step - loss: 0.0776 - acc: 0.9582 - val_loss: 0.1496 - val_acc: 0.9111
# Epoch 63/85
# 359/359 [==============================] - 0s 42us/step - loss: 0.0763 - acc: 0.9721 - val_loss: 0.1312 - val_acc: 0.9222
# Epoch 64/85
# 359/359 [==============================] - 0s 53us/step - loss: 0.0811 - acc: 0.9694 - val_loss: 0.1285 - val_acc: 0.9222
# Epoch 65/85
# 359/359 [==============================] - 0s 48us/step - loss: 0.1009 - acc: 0.9471 - val_loss: 0.1194 - val_acc: 0.9444
# Epoch 66/85
# 359/359 [==============================] - 0s 41us/step - loss: 0.0777 - acc: 0.9694 - val_loss: 0.1231 - val_acc: 0.9222
# Epoch 67/85
# 359/359 [==============================] - 0s 47us/step - loss: 0.0816 - acc: 0.9638 - val_loss: 0.1206 - val_acc: 0.9444
# Epoch 68/85
# 359/359 [==============================] - 0s 41us/step - loss: 0.1001 - acc: 0.9582 - val_loss: 0.1156 - val_acc: 0.9444
# Epoch 69/85
# 359/359 [==============================] - 0s 46us/step - loss: 0.0937 - acc: 0.9582 - val_loss: 0.1261 - val_acc: 0.9222
# Epoch 70/85
# 359/359 [==============================] - 0s 44us/step - loss: 0.0843 - acc: 0.9471 - val_loss: 0.1233 - val_acc: 0.9333
# Epoch 71/85
# 359/359 [==============================] - 0s 42us/step - loss: 0.0944 - acc: 0.9638 - val_loss: 0.1406 - val_acc: 0.9222
# Epoch 72/85
# 359/359 [==============================] - 0s 48us/step - loss: 0.0772 - acc: 0.9721 - val_loss: 0.1324 - val_acc: 0.9222
# Epoch 73/85
# 359/359 [==============================] - 0s 50us/step - loss: 0.1093 - acc: 0.9554 - val_loss: 0.1189 - val_acc: 0.9444
# Epoch 74/85
# 359/359 [==============================] - 0s 50us/step - loss: 0.0855 - acc: 0.9638 - val_loss: 0.1244 - val_acc: 0.9444
# Epoch 75/85
# 359/359 [==============================] - 0s 675us/step - loss: 0.1346 - acc: 0.9471 - val_loss: 0.1259 - val_acc: 0.9333
# Epoch 76/85
# 359/359 [==============================] - 0s 50us/step - loss: 0.0741 - acc: 0.9610 - val_loss: 0.1177 - val_acc: 0.9444
# Epoch 77/85
# 359/359 [==============================] - 0s 51us/step - loss: 0.0821 - acc: 0.9610 - val_loss: 0.1448 - val_acc: 0.9111
# Epoch 78/85
# 359/359 [==============================] - 0s 43us/step - loss: 0.0947 - acc: 0.9666 - val_loss: 0.1430 - val_acc: 0.9111
# Epoch 79/85
# 359/359 [==============================] - 0s 51us/step - loss: 0.1461 - acc: 0.9387 - val_loss: 0.1184 - val_acc: 0.9333
# Epoch 80/85
# 359/359 [==============================] - 0s 45us/step - loss: 0.0832 - acc: 0.9610 - val_loss: 0.1413 - val_acc: 0.9000
# Epoch 81/85
# 359/359 [==============================] - 0s 42us/step - loss: 0.0857 - acc: 0.9694 - val_loss: 0.1353 - val_acc: 0.9111
# Epoch 82/85
# 359/359 [==============================] - 0s 45us/step - loss: 0.0797 - acc: 0.9694 - val_loss: 0.1266 - val_acc: 0.9222
# Epoch 83/85
# 359/359 [==============================] - 0s 41us/step - loss: 0.1084 - acc: 0.9610 - val_loss: 0.1289 - val_acc: 0.9222
# Epoch 84/85
# 359/359 [==============================] - 0s 48us/step - loss: 0.0973 - acc: 0.9554 - val_loss: 0.1203 - val_acc: 0.9333
# Epoch 85/85
# 359/359 [==============================] - 0s 43us/step - loss: 0.0957 - acc: 0.9526 - val_loss: 0.1240 - val_acc: 0.9333
# 6
# ['Donovan Mitchell' 'Kyle Kuzma' 'Lauri Markkanen' 'Jayson Tatum'
#  'John Collins' 'Ben Simmon']

# %%
plt.figure(1)
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc = 'lower right')
plt.show()

# %%
plt.figure(2)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc = 'upper right')
plt.show()
